# %% [markdown]
# # evolución temporal o tendencia
#
# tendencia de prestamo por formato

# %%
from lib.conexion_BBDD import get_connection
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import pandas as pd


def obtener_datos_tiempo():
    conn = get_connection()
    query = "select fecha, count(*) as cantidad_prestamos from prestamos group by fecha order by fecha"
    df = pd.read_sql(query, conn)
    conn.close()
    return df

df = obtener_datos_tiempo()

fig = px.line(
    df,
    x="fecha",
    y="cantidad_prestamos",
    title="Evolución temporal de préstamos",
    markers=True, # añadir puntos en la uniones
)
fig.show()


# grafico de comparacion
query = "select formato, count(id_prestamo) as total_prestamos from prestamos group by formato;"



fig = px.bar(
    df, 
    x='formato', 
    y='total_prestamos', 
    title='Comparativa de Préstamos por formato',
    color='formato',
    text_auto=True
)

fig.show()
# Out:
# Error: 2003: Can't connect to MySQL server on 'localhost:3306' (Errno 10061: No se puede establecer una conexión ya que el equipo de destino denegó expresamente dicha conexión)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 17
#      13     # Importante: convertir a formato fecha
#      14     df['fecha'] = pd.to_datetime(df['fecha'])
#      15     return df
#      16
# ---> 17 df = obtener_datos_tiempo()
#      18
#      19 fig = px.line(
#      20     df,
#
# Cell In[1], line 11, in obtener_datos_tiempo()
#       8 def obtener_datos_tiempo():
#       9     conn = get_connection()
#      10     query = "select fecha, count(*) as cantidad_prestamos from prestamos group by fecha order by fecha"
# ---> 11     df = pd.read_sql(query, conn)
#      12     conn.close()
#      13     # Importante: convertir a formato fecha
#      14     df['fecha'] = pd.to_datetime(df['fecha'])
#
# File c:\Users\miriam1\Documents\proyecto_final_curso\.venv\Lib\site-packages\pandas\io\sql.py:702, in read_sql(sql, con, index_col, coerce_float, params, parse_dates, columns, chunksize, dtype_backend, dtype)
#     700 with pandasSQL_builder(con) as pandas_sql:
#     701     if isinstance(pandas_sql, SQLiteDatabase):
# --> 702         return pandas_sql.read_query(
#     703             sql,
#     704             index_col=index_col,
#     705             params=params,
#     706             coerce_float=coerce_float,
#     707             parse_dates=parse_dates,
#     708             chunksize=chunksize,
#     709             dtype_backend=dtype_backend,
#     710             dtype=dtype,
#     711         )
#     713     try:
#     714         _is_table_name = pandas_sql.has_table(sql)
#
# File c:\Users\miriam1\Documents\proyecto_final_curso\.venv\Lib\site-packages\pandas\io\sql.py:2766, in SQLiteDatabase.read_query(self, sql, index_col, coerce_float, parse_dates, params, chunksize, dtype, dtype_backend)
#    2755 def read_query(
#    2756     self,
#    2757     sql,
#    (...)   2764     dtype_backend: DtypeBackend | Literal["numpy"] = "numpy",
#    2765 ) -> DataFrame | Iterator[DataFrame]:
# -> 2766     cursor = self.execute(sql, params)
#    2767     columns = [col_desc[0] for col_desc in cursor.description]
#    2769     if chunksize is not None:
#
# File c:\Users\miriam1\Documents\proyecto_final_curso\.venv\Lib\site-packages\pandas\io\sql.py:2700, in SQLiteDatabase.execute(self, sql, params)
#    2698     raise TypeError("Query must be a string unless using sqlalchemy.")
#    2699 args = [] if params is None else [params]
# -> 2700 cur = self.con.cursor()
#    2701 try:
#    2702     cur.execute(sql, *args)
#
# AttributeError: 'NoneType' object has no attribute 'cursor'
