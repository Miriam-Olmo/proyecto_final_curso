# %% [markdown]
# # 1. Importacion a excel/ google sheet
#
# primero obtenemos los datos de un formato csv y lo pasamos a excel/google sheet. hemos puesto nombre al archivo para guardarlo y cambiado el nombre a la hoja de cada fichero. (hemos obtenido dos excel distintos).
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # 2. scripts limpieza
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # 3. conexion con base de datos mysql
#
# ![image.png](attachment:image.png)

# %% [markdown]
# # 4. creacion base de datos en workbech
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # 5. main.py
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # 6. visualizacion interactiva

# %% [markdown]
# ## 6.1. grafico evolucion temporal(line)
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## 6.2. grafico de comparacion (bar)
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ## 6.3. grafico de distribucion (pie)
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
